# %%
import pandas as pd
import numpy as np
import plotly.express as px

# Read in the data
observations_r = pd.read_csv('observations.csv')
species_r = pd.read_csv('species_info.csv')

# Sum the observations for each species in each park
observations = observations_r.pivot_table(index=['scientific_name', 'park_name'], values='observations', aggfunc='sum').reset_index()

# Remove entries of species_r which have the same entries in scientific_name and keep selected conservation_status
species_r = species_r.drop_duplicates(subset=['scientific_name', 'conservation_status'], keep='first')
species = species_r.drop([8,560])

# Merge the two dataframes to analyze obersevations by species and their conservation status
wildlife = pd.merge(observations, species, on='scientific_name', how='left')

# %% [markdown]
# # EDA
# - [X] Check data-types
# - [X] Check cleanliness
# - [X] Remove duplicates in both df before merging and check merge
# - [ ] Check univariate
# - [ ] Check association

# %%
display(wildlife.head())
display(wildlife.info())
display(wildlife.describe(include='all'))
# Out:
#   scientific_name                            park_name  observations  \
# 0   Abies bifolia                  Bryce National Park           109
# 1   Abies bifolia  Great Smoky Mountains National Park            72
# 2   Abies bifolia            Yellowstone National Park           215
# 3   Abies bifolia               Yosemite National Park           136
# 4  Abies concolor                  Bryce National Park            83
#
#          category                                       common_names  \
# 0  Vascular Plant                          Rocky Mountain Alpine Fir
# 1  Vascular Plant                          Rocky Mountain Alpine Fir
# 2  Vascular Plant                          Rocky Mountain Alpine Fir
# 3  Vascular Plant                          Rocky Mountain Alpine Fir
# 4  Vascular Plant  Balsam Fir, Colorado Fir, Concolor Fir, Silver...
#
#   conservation_status
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22164 entries, 0 to 22163
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   scientific_name      22164 non-null  object
#  1   park_name            22164 non-null  object
#  2   observations         22164 non-null  int64
#  3   category             22164 non-null  object
#  4   common_names         22164 non-null  object
#  5   conservation_status  716 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 1.0+ MB
# None
#        scientific_name            park_name  observations        category  \
# count            22164                22164  22164.000000           22164
# unique            5541                    4           NaN               7
# top      Abies bifolia  Bryce National Park           NaN  Vascular Plant
# freq                 4                 5541           NaN           17048
# mean               NaN                  NaN    149.555089             NaN
# std                NaN                  NaN     81.421299             NaN
# min                NaN                  NaN      9.000000             NaN
# 25%                NaN                  NaN     88.000000             NaN
# 50%                NaN                  NaN    129.000000             NaN
# 75%                NaN                  NaN    217.000000             NaN
# max                NaN                  NaN    805.000000             NaN
#
#               common_names conservation_status
# count                22164                 716
# unique                5229                   4
# top     Brachythecium Moss  Species of Concern
# freq                    28                 604
# mean                   NaN                 NaN
# std                    NaN                 NaN
# min                    NaN                 NaN
# 25%                    NaN                 NaN
# 50%                    NaN                 NaN
# 75%                    NaN                 NaN
# max                    NaN                 NaN

# %% [markdown]
# |Name|Description|
# |----|-----------|
# |Scientific name|It is the latin name for each species, which occures one time per park(there are 4 different parks).Hence, there are 22164/4 = 5541 unique species|
# |Observations|are the number of observations per species per park. Ranges between 9 - 805 with median of 150|
# |Category|is the category into which the observed species can be grouped|
# |Common names|are the usually used names for each species|
# |Conservation status|is the status of the oberved entity|
#
# ## Research questions
# 1. Which species has the most observations? Which one has the least?
# 2. Which categories have the most observations? Which ones have the least?
# 3. Relationship between category and conservation status
# 4. How many observations are made for each conservation status?
# 5. Which parks have the most unique species?
# 6. Which parks have the most overall observations?
# 7. Which parks host the most endangered species?
# 8. Observations by Conservation Status and Park

# %% [markdown]
# ## 1. Which species has the most observations? Which one has the least?

# %%
top10 = wildlife.groupby('common_names').observations.sum().nlargest(10).reset_index()
least10 = wildlife.groupby('common_names').observations.sum().nsmallest(10).reset_index()

fig = px.bar(top10, x='common_names', y='observations', title='Top 10 Species by Observations')
fig.show()
# Out:
# <div>                            <div id="00067479-eca9-4c9b-9d4d-5ff625704ef4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00067479-eca9-4c9b-9d4d-5ff625704ef4")) {                    Plotly.newPlot(                        "00067479-eca9-4c9b-9d4d-5ff625704ef4",                        [{"alignmentgroup":"True","hovertemplate":"common_names=%{x}\u003cbr\u003eobservations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Dicranum Moss","Brachythecium Moss","Panic Grass","Bryum Moss","Sphagnum","Hypnum Moss","Hygrohypnum Moss","Anomodon Moss","A Sedge, Sedge","Pohlia Moss"],"xaxis":"x","y":[4008,3910,3543,3477,3476,2955,2845,2384,2336,2330],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode" ...

# %%
fig = px.bar(least10, x='common_names', y='observations', title='Top 10 Species by Observations')
fig.show()
# Out:
# <div>                            <div id="98565c71-a9fd-4af8-bcb6-926b60d03c33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98565c71-a9fd-4af8-bcb6-926b60d03c33")) {                    Plotly.newPlot(                        "98565c71-a9fd-4af8-bcb6-926b60d03c33",                        [{"alignmentgroup":"True","hovertemplate":"common_names=%{x}\u003cbr\u003eobservations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Whooping Crane","Red Wolf","Bachman's Warbler, Bachman's Wood Warbler","Smoky Madtom","Sierra Nevada Yellow-Legged Frog","Indiana Bat, Indiana Or Social Myotis","June Sucker","Red-Cockaded Woodpecker","Carolina Northern Flying Squirrel, Northern Flying Squirrel","Sierra Nevada Bighorn Sheep"],"xaxis":"x","y":[131,137,141,143,144,145,146,146,153,153],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{" ...

# %% [markdown]
# ## 2. Which categories have the most observations? Which ones have the least?

# %%
top10_cat = wildlife.groupby('category').observations.sum().nlargest(10).reset_index()
least10_cat = wildlife.groupby('category').observations.sum().nsmallest(10).reset_index()

fig = px.bar(wildlife, x='category', y='observations', title='Top 10 Species by Observations')
fig.show()
# Out:
# <div>                            <div id="0b901522-9d21-4992-8365-432a014108f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b901522-9d21-4992-8365-432a014108f8")) {                    Plotly.newPlot(                        "0b901522-9d21-4992-8365-432a014108f8",                        [{"alignmentgroup":"True","hovertemplate":"category=%{x}\u003cbr\u003eobservations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Vascular Plant","Bird","Nonvascular Plant","Mammal","Fish","Reptile","Amphibian"],"xaxis":"x","y":[2555090,292833,190653,116696,70818,44678,43971],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scat ...

# %% [markdown]
# ## 4. How many observations are made for each conservation status?

# %%
fig = px.histogram(wildlife, x='conservation_status', y='observations', title='Observations by Conservation Status')
fig.show()
# Out:
# <div>                            <div id="9c8a2119-d46c-4499-9e98-640bcf304f89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c8a2119-d46c-4499-9e98-640bcf304f89")) {                    Plotly.newPlot(                        "9c8a2119-d46c-4499-9e98-640bcf304f89",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"conservation_status=%{x}\u003cbr\u003esum of observations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[null,null,null,null,null,null,null,null,"Species of Concern","Species of Concern","Species of Concern","Species of Concern",null,null,null,null,"Species of Concern","Species of Concern","Species of Concern","Species of Concern",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"Species of Concern","Species of Concern","Species of Concern","Species of Concern",null,null,null,null,"Species of Concern","Species of Concern","Species of Concern","Species of Concern",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"Species of Concern","Species of Concern","Species of Concern","Species of Concern",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"Species of Concern","Species of Concern","Species of Concern","Species of Concern",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"Species of Concern","Species of Concern","Species of Concern","Species of Concern",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null, ...

# %% [markdown]
# ## 8.Observations by Conservation Status and Park

# %%
fig = px.histogram(wildlife, x='category', y='observations', color='park_name',
                    barmode='group', title='Observations by Conservation Status and Park')
fig.show()
# Out:
# <div>                            <div id="fc461697-d9fd-4f42-9345-f314a4ab3267" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc461697-d9fd-4f42-9345-f314a4ab3267")) {                    Plotly.newPlot(                        "fc461697-d9fd-4f42-9345-f314a4ab3267",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"park_name=Bryce National Park\u003cbr\u003ecategory=%{x}\u003cbr\u003esum of observations=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bryce National Park","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bryce National Park","offsetgroup":"Bryce National Park","orientation":"v","showlegend":true,"x":["Vascular Plant","Vascular Plant","Vascular Plant","Nonvascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Bird","Bird","Bird","Bird","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Amphibian","Nonvascular Plant","Vascular Plant","Vascular Plant","Bird","Bird","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Bird","Bird","Vascular Plant","Bird","Bird","Bird","Vascular Plant","Bird","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Bird","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Reptile","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Bird","Bird","Vascular Plant","Bird","Vascular Plant","Vascular Plant","Vascular Plant","Mammal","Mammal","Bird","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Fish","Nonvascular Plant","Nonvascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Vascular Plant","Amphibian","Amphibian","Amphibian","Amphibian","Fish","Fish","Vascular Plant","Va ...
